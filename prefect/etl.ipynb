# %%
import os
import pandas as pd
from pathlib import Path

# %%
def load(filename: str) -> pd.DataFrame:
    
    df_iter = pd.read_csv(filename, iterator=True, chunksize=10000)
    return df_iter

# %%
def fetch(df_iter: pd.DataFrame) -> pd.DataFrame:
    """Read one chunk"""
    df = next(df_iter)
    df = df[df['language'] == 'english']
    df = df.replace('\\n', '', regex = True)
    df = df.reset_index(drop=True)
    return df

# %%
source_path = "/home/aliciescont/Documents/Github/dezoomcamp-project/data/steam_reviews.csv"
df_iter = pd.read_csv(source_path, iterator=True, chunksize=500000, index_col=0)

df = next(iter(df_iter))

# %%
source_path = "/home/aliciescont/Documents/Github/dezoomcamp-project/data/steam_reviews.csv"
df_iter = pd.read_csv(source_path, iterator=True, chunksize=500000, index_col=0)

index_file = 0
while True:
    try:
        index_file += 1
        df_next = fetch(df_iter)
        print(df_next.head())
        path = Path(f"{source_path}_{index_file}.csv") 
        df_next.to_csv(path,index=False)
    except StopIteration:
        print("Finished ingesting data into the postgres database")
        break
# Out:
#    app_id                  app_name  review_id language  \
# 0  292030  The Witcher 3: Wild Hunt   85184605  english
# 1  292030  The Witcher 3: Wild Hunt   85184171  english
# 2  292030  The Witcher 3: Wild Hunt   85184064  english
# 3  292030  The Witcher 3: Wild Hunt   85180436  english
# 4  292030  The Witcher 3: Wild Hunt   85179753  english
#
#                                               review  timestamp_created  \
# 0  One of the best RPG's of all time, worthy of a...         1611379970
# 1             good story, good graphics. lots to do.         1611379264
# 2                                           dis gud,         1611379091
# 3  favorite game of all time cant wait for the Ne...         1611373086
# 4                          Why wouldn't you get this         1611371978
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1611379970         True              0            0  ...
# 1         1611379264         True              0            0  ...
# 2         1611379091         True              0            0  ...
# 3         1611373086         True              0            0  ...
# 4         1611371978         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1            True              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561199054755373                       5                   3
# 1  76561198170193529                      11                   1
# 2  76561198119302812                      27                   2
# 3  76561198065591528                      33                   1
# 4  76561198996835044                     131                   2
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   5587.0                          3200.0
# 1                    823.0                           823.0
# 2                   4192.0                          3398.0
# 3                  23329.0                           177.0
# 4                   8557.0                          2004.0
#
#    author.playtime_at_review  author.last_played
# 0                     5524.0        1.611384e+09
# 1                      823.0        1.611379e+09
# 2                     4192.0        1.611352e+09
# 3                    23329.0        1.611219e+09
# 4                     8557.0        1.611371e+09
#
# [5 rows x 22 columns]
#    app_id   app_name  review_id language  \
# 0      70  Half-Life   49797168  english
# 1      70  Half-Life   49794752  english
# 2      70  Half-Life   49792060  english
# 3      70  Half-Life   49789951  english
# 4      70  Half-Life   49774359  english
#
#                                               review  timestamp_created  \
# 0  Revolutionary for its time. Everyone who likes...         1553730955
# 1                                               epic         1553718371
# 2  Still one of the best. A true classic that wil...         1553707971
# 3  Undeniable classic by all means, but struggles...         1553700218
# 4  A timeless classic, engaging story, paced acti...         1553622327
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1553730955         True              2            0  ...
# 1         1553718371         True              0            0  ...
# 2         1553707971         True              0            0  ...
# 3         1553700218         True              0            0  ...
# 4         1553622327         True              5            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1            True              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198211527372                     140                  27
# 1  76561198346598883                      44                   3
# 2  76561198226064900                      45                   1
# 3  76561198116436100                     145                  30
# 4  76561198024955378                     173                  11
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                    761.0                             0.0
# 1                    379.0                             0.0
# 2                    520.0                             0.0
# 3                   1410.0                             0.0
# 4                    135.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                      354.0        1.604165e+09
# 1                      378.0        1.575062e+09
# 2                      206.0        1.597727e+09
# 3                     1410.0        1.520682e+09
# 4                      129.0        1.575561e+09
#
# [5 rows x 22 columns]
#    app_id     app_name  review_id language  \
# 0    4000  Garry's Mod   71813207  english
# 1    4000  Garry's Mod   71812190  english
# 2    4000  Garry's Mod   71811142  english
# 3    4000  Garry's Mod   71810551  english
# 4    4000  Garry's Mod   71810378  english
#
#                                               review  timestamp_created  \
# 0                                             noyeet         1593616656
# 1  This game is endless, which makes it great!Inf...         1593615734
# 2     old but gold, always abit of fun now and again         1593614809
# 3  Love this game helps boredom during COVID-19 L...         1593614218
# 4                        Hey... This is pretty good.         1593614072
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1593616656         True              0            0  ...
# 1         1593615734         True              0            0  ...
# 2         1593614809         True              1            0  ...
# 3         1593614218         True              0            0  ...
# 4         1593614072         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1            True              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198978835794                       2                   1
# 1  76561198324119957                      14                   6
# 2  76561198135094552                      58                   3
# 3  76561198364632895                      12                   1
# 4  76561199036788398                      15                   3
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                    789.0                             0.0
# 1                  19841.0                             0.0
# 2                  21359.0                             0.0
# 3                   1852.0                             0.0
# 4                  13330.0                          1341.0
#
#    author.playtime_at_review  author.last_played
# 0                      738.0        1.593624e+09
# 1                    18706.0        1.604761e+09
# 2                    20171.0        1.604097e+09
# 3                     1813.0        1.603875e+09
# 4                     1611.0        1.611085e+09
#
# [5 rows x 22 columns]
#    app_id     app_name  review_id language  \
# 0    4000  Garry's Mod   11020579  english
# 1    4000  Garry's Mod   11020319  english
# 2    4000  Garry's Mod   11020218  english
# 3    4000  Garry's Mod   11020168  english
# 4    4000  Garry's Mod   11019838  english
#
#                                               review  timestamp_created  \
# 0  Do I need to say anything? Just get it, play i...         1404310671
# 1               Holy Crap don't even get me started.         1404309662
# 2  i love this game with all its gamemodes and aw...         1404309255
# 3  Wonderful game no doubt! I love the aspect of ...         1404309100
# 4  Garry's mod is a really fun game because you h...         1404307861
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1404310671         True              3            0  ...
# 1         1404309662         True              2            2  ...
# 2         1439926969         True              0            0  ...
# 3         1404309100         True              1            0  ...
# 4         1404307861         True              1            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0           False              False                        False
# 1            True              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198062394818                     134                   6
# 1  76561198063300572                     345                  10
# 2  76561198111605917                      98                  10
# 3  76561198056437010                     111                   3
# 4  76561198134611871                     498                  15
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   5274.0                             0.0
# 1                 258414.0                             0.0
# 2                  13591.0                             0.0
# 3                   8253.0                             0.0
# 4                  19833.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                     2873.0        1.505086e+09
# 1                    50949.0        1.587021e+09
# 2                    10283.0        1.546741e+09
# 3                     5159.0        1.568335e+09
# 4                     8187.0        1.558130e+09
#
# [5 rows x 22 columns]
#    app_id          app_name  review_id language  \
# 0  381210  Dead by Daylight   46558893  english
# 1  381210  Dead by Daylight   46558396  english
# 2  381210  Dead by Daylight   46557761  english
# 3  381210  Dead by Daylight   46556451  english
# 4  381210  Dead by Daylight   46555809  english
#
#                                               review  timestamp_created  \
# 0  one of the most fun bringing games ever. still...         1542972355
# 1  absolutley awesome game. great to play with fr...         1542972160
# 2                                          Good game         1542971904
# 3  Ive been watching the progress of this game fr...         1542971362
# 4                      Takes too long to find a room         1542971091
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1542972355         True              1            0  ...
# 1         1542972160         True              1            0  ...
# 2         1542971904         True              1            0  ...
# 3         1574976014         True              0            0  ...
# 4         1542971091         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1           False              False                        False
# 2            True              False                        False
# 3           False              False                        False
# 4           False              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198039258287                     128                   7
# 1  76561198235851444                     172                   6
# 2  76561198291103303                     323                 127
# 3  76561198070064672                     278                   7
# 4  76561198151305593                      51                   3
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                  17230.0                             0.0
# 1                    401.0                             0.0
# 2                    289.0                             0.0
# 3                  52469.0                          1665.0
# 4                   9087.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                     9724.0        1.609116e+09
# 1                      401.0        1.542972e+09
# 2                       78.0        1.565709e+09
# 3                    15430.0        1.610637e+09
# 4                     1998.0        1.604114e+09
#
# [5 rows x 22 columns]
#    app_id          app_name  review_id language           review  \
# 0  477160  Human: Fall Flat   65134520  english              yes
# 1  477160  Human: Fall Flat   65133856  english       great game
# 2  477160  Human: Fall Flat   65133303  english        Very Epic
# 3  477160  Human: Fall Flat   65132837  english  it is nice game
# 4  477160  Human: Fall Flat   65131447  english       vhfsdgherg
#
#    timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 0         1584345846         1584345846         True              0
# 1         1584344634         1584344634         True              0
# 2         1584343718         1584343718         True              1
# 3         1584342830         1584342830         True              0
# 4         1584340358         1584340358         True              0
#
#    votes_funny  ...  steam_purchase  received_for_free  \
# 0            0  ...            True              False
# 1            0  ...            True              False
# 2            0  ...            True              False
# 3            0  ...            True              False
# 4            0  ...           False              False
#
#    written_during_early_access     author.steamid  author.num_games_owned  \
# 0                        False  76561198394156304                     335
# 1                        False  76561198913362171                       9
# 2                        False  76561198816759100                      16
# 3                        False  76561198091377017                      43
# 4                        False  76561198872539274                      16
#
#    author.num_reviews  author.playtime_forever  \
# 0                   9                    672.0
# 1                  10                    178.0
# 2                   4                   3850.0
# 3                   8                   1684.0
# 4                  15                    471.0
#
#    author.playtime_last_two_weeks  author.playtime_at_review  \
# 0                             0.0                      564.0
# 1                             0.0                       58.0
# 2                             0.0                     3034.0
# 3                             0.0                     1178.0
# 4                             0.0                      325.0
#
#    author.last_played
# 0        1.596790e+09
# 1        1.594400e+09
# 2        1.605822e+09
# 3        1.609140e+09
# 4        1.600425e+09
#
# [5 rows x 22 columns]
#    app_id    app_name  review_id language  \
# 0  242760  The Forest   13749986  english
# 1  242760  The Forest   13749898  english
# 2  242760  The Forest   13749755  english
# 3  242760  The Forest   13749409  english
# 4  242760  The Forest   13749401  english
#
#                                               review  timestamp_created  \
# 0  Played the game all afternoon, only crashed on...         1420075267
# 1    Good game,Saw a female cannibal's breasts 11/10         1420074907
# 2  Honestly one of my favorite games i've ever pl...         1420074356
# 3  if you need to releive some psycotic tendencie...         1420072931
# 4  Best game ever!!P.S. Pit out updates a bit fas...         1420072896
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1420075267         True              0            0  ...
# 1         1420074935         True              2            1  ...
# 2         1584698363         True              0            0  ...
# 3         1420072931         True              0            0  ...
# 4         1420072896         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                         True
# 1            True              False                         True
# 2            True              False                        False
# 3            True              False                         True
# 4            True              False                         True
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198041119223                     299                  13
# 1  76561198117841226                      78                   3
# 2  76561198055482936                     313                  13
# 3  76561198056295548                     197                  49
# 4  76561198126712831                      35                   1
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   1849.0                             0.0
# 1                   3117.0                             0.0
# 2                   2089.0                             0.0
# 3                   9197.0                             0.0
# 4                   7703.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                      659.0        1.565862e+09
# 1                      466.0        1.601930e+09
# 2                     2089.0        1.584698e+09
# 3                      548.0        1.603587e+09
# 4                     1780.0        1.584898e+09
#
# [5 rows x 22 columns]
#    app_id        app_name  review_id language  \
# 0   40800  Super Meat Boy   71401274  english
# 1   40800  Super Meat Boy   71376239  english
# 2   40800  Super Meat Boy   71362783  english
# 3   40800  Super Meat Boy   71353657  english
# 4   40800  Super Meat Boy   71333739  english
#
#                                               review  timestamp_created  \
# 0  I've sunk a silly amount of time into this acr...         1593178332
# 1                Into the meat grinder...Repeatedly.         1593155718
# 2  This game may be difficult, ESPECIALLY with Th...         1593140459
# 3    🟥🟥🟥🟥🟥⚫⚫🟥🟥 ‏‏‎  ‏‏‎ ‏‏‎︶ ‏‏‎ ‏‏‎ 🟥🟥🟥🟥🟥great game         1593129924
# 4  i was having a good day sharing some cheeky la...         1593110241
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1593178332         True              0            0  ...
# 1         1593155718         True              5            2  ...
# 2         1593140459         True              0            0  ...
# 3         1593130194         True              0            0  ...
# 4         1593110241        False              0            9  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0           False              False                        False
# 1            True              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561197960675009                     327                   4
# 1  76561198061262969                      85                   3
# 2  76561198971269146                      20                   1
# 3  76561198274199883                     141                  15
# 4  76561198254364102                      74                  16
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   1627.0                             0.0
# 1                    556.0                             0.0
# 2                   1530.0                             1.0
# 3                     97.0                             0.0
# 4                    206.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                     1627.0        1.426536e+09
# 1                       21.0        1.598960e+09
# 2                     1511.0        1.609742e+09
# 3                       97.0        1.603315e+09
# 4                      202.0        1.593112e+09
#
# [5 rows x 22 columns]
#    app_id               app_name  review_id language  \
# 0  581320  Insurgency: Sandstorm   49326880  english
# 1  581320  Insurgency: Sandstorm   49326843  english
# 2  581320  Insurgency: Sandstorm   49326419  english
# 3  581320  Insurgency: Sandstorm   49326354  english
# 4  581320  Insurgency: Sandstorm   49325919  english
#
#                                               review  timestamp_created  \
# 0  Is it better than the old insurgency? i was sk...         1551579353
# 1  The Nightfall and Operation Breakaway updates ...         1551579228
# 2  7 months after launch date, still no modding o...         1551576839
# 3  Just need more maps, more things for the coop ...         1551576482
# 4  FINAL REVIEW -OCTOBER 29, 2019:(other updates ...         1551573975
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1551581429         True              0            0  ...
# 1         1600617128         True              1            0  ...
# 2         1554877957        False             30            1  ...
# 3         1551576482         True              0            0  ...
# 4         1572408417        False              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1            True              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561197999510430                     122                  26
# 1  76561198040215054                     257                  45
# 2  76561197992611636                    1071                  20
# 3  76561198271934123                     116                  18
# 4  76561198294141311                      37                   1
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   9438.0                             0.0
# 1                  16079.0                             0.0
# 2                  31753.0                             0.0
# 3                   3757.0                             0.0
# 4                   8720.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                     1998.0        1.607300e+09
# 1                    14480.0        1.609138e+09
# 2                    31641.0        1.553137e+09
# 3                     2331.0        1.595387e+09
# 4                     8720.0        1.572211e+09
#
# [5 rows x 22 columns]
#    app_id          app_name  review_id language  \
# 0  431960  Wallpaper Engine   83368049  english
# 1  431960  Wallpaper Engine   83367950  english
# 2  431960  Wallpaper Engine   83366662  english
# 3  431960  Wallpaper Engine   83366587  english
# 4  431960  Wallpaper Engine   83366452  english
#
#                                               review  timestamp_created  \
# 0                                    best thing ever         1609140434
# 1  Great software, full of creative and beautiful...         1609140325
# 2                                                yes         1609138782
# 3                                               yeah         1609138692
# 4                                      very good sir         1609138513
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1609140434         True              0            0  ...
# 1         1609140325         True              0            0  ...
# 2         1609138782         True              0            0  ...
# 3         1609138692         True              0            0  ...
# 4         1609138513         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1            True              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198353405373                      17                   4
# 1  76561198069237160                     286                  55
# 2  76561198320385799                      12                   4
# 3  76561198411179237                      35                   5
# 4  76561199015669260                      25                   2
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   4157.0                             1.0
# 1                   5458.0                             0.0
# 2                    791.0                             0.0
# 3                   2509.0                             0.0
# 4                    297.0                            18.0
#
#    author.playtime_at_review  author.last_played
# 0                     4157.0        1.609628e+09
# 1                     5458.0        1.609140e+09
# 2                      181.0        1.609401e+09
# 3                     2503.0        1.609225e+09
# 4                      278.0        1.610593e+09
#
# [5 rows x 22 columns]
#    app_id       app_name  review_id language  \
# 0  397540  Borderlands 3   74032272  english
# 1  397540  Borderlands 3   74031792  english
# 2  397540  Borderlands 3   74030475  english
# 3  397540  Borderlands 3   74030204  english
# 4  397540  Borderlands 3   74030198  english
#
#                                               review  timestamp_created  \
# 0                                  It's Borderlands!         1596983721
# 1                           More like Boringlands 3.         1596983148
# 2  too many  bugs. too expensive if you buy every...         1596981326
# 3  There's a ton of content on this game compared...         1596980954
# 4  i love it they best fps taht implements story ...         1596980948
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1596983721         True              0            0  ...
# 1         1596983148        False              8            8  ...
# 2         1609369513        False              0            0  ...
# 3         1596980954         True              0            0  ...
# 4         1596980948         True              0            1  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1           False              False                        False
# 2           False              False                        False
# 3            True              False                        False
# 4           False               True                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561197997114640                     176                   8
# 1  76561197999372741                    1560                 110
# 2  76561198991806078                      14                   4
# 3  76561198043811682                      30                   3
# 4  76561198128227010                      34                   2
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   1970.0                             0.0
# 1                   1516.0                             0.0
# 2                   6428.0                           316.0
# 3                   4512.0                             0.0
# 4                     81.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                     1187.0        1.605470e+09
# 1                     1516.0        1.596983e+09
# 2                     5832.0        1.609890e+09
# 3                     4068.0        1.597462e+09
# 4                       49.0        1.603556e+09
#
# [5 rows x 22 columns]
#     app_id            app_name  review_id language  \
# 0  1158310  Crusader Kings III   81439989  english
# 1  1158310  Crusader Kings III   81439834  english
# 2  1158310  Crusader Kings III   81439770  english
# 3  1158310  Crusader Kings III   81439652  english
# 4  1158310  Crusader Kings III   81439369  english
#
#                                               review  timestamp_created  \
# 0  I was high king of Norway. I was a dreadful, f...         1606881956
# 1  First Iron Man:I am Dfynwallow of Wales. I sha...         1606881702
# 2  You can become the King of Kong; what else do ...         1606881597
# 3  This game is so addictive! I have been playing...         1606881387
# 4  This game is awesome. It improves upon everyth...         1606880968
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1606882165         True              0            0  ...
# 1         1607214951         True              0            0  ...
# 2         1606881597         True              0            0  ...
# 3         1606881387         True              0            0  ...
# 4         1606880968         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0           False              False                        False
# 1            True              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198052463484                      90                  13
# 1  76561198064877447                     278                  16
# 2  76561198049594505                     357                   4
# 3  76561198083110631                      63                   3
# 4  76561198252268390                      17                   7
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   3161.0                             0.0
# 1                   4930.0                          1061.0
# 2                   6225.0                             0.0
# 3                   2973.0                             0.0
# 4                   4261.0                           374.0
#
#    author.playtime_at_review  author.last_played
# 0                     1482.0        1.608357e+09
# 1                     1982.0        1.610789e+09
# 2                     4771.0        1.608900e+09
# 3                     1833.0        1.608001e+09
# 4                      456.0        1.610751e+09
#
# [5 rows x 22 columns]
#    app_id                        app_name  review_id language  \
# 0  359550  Tom Clancy's Rainbow Six Siege   72041541  english
# 1  359550  Tom Clancy's Rainbow Six Siege   72041522  english
# 2  359550  Tom Clancy's Rainbow Six Siege   72041424  english
# 3  359550  Tom Clancy's Rainbow Six Siege   72041175  english
# 4  359550  Tom Clancy's Rainbow Six Siege   72041154  english
#
#                                            review  timestamp_created  \
# 0                                             fun         1593890419
# 1                                  game sucks ass         1593890385
# 2                                       Great fun         1593890277
# 3                                             gud         1593890018
# 4  It's fun but lot of dumb bugs and Client sided         1593889996
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1593890419         True              0            0  ...
# 1         1593890385        False              0            0  ...
# 2         1593890277         True              0            0  ...
# 3         1593890018         True              0            0  ...
# 4         1593889996         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1           False              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561199000056990                      11                   2
# 1  76561199048165237                      26                   2
# 2  76561198301841860                      11                   1
# 3  76561198875068224                      25                   6
# 4  76561198215714664                      46                   1
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   2187.0                             0.0
# 1                   9146.0                             0.0
# 2                   3038.0                             1.0
# 3                   3034.0                             0.0
# 4                  86091.0                           284.0
#
#    author.playtime_at_review  author.last_played
# 0                     1170.0        1.606509e+09
# 1                     4012.0        1.600916e+09
# 2                      817.0        1.609926e+09
# 3                     1056.0        1.606577e+09
# 4                    76237.0        1.610687e+09
#
# [5 rows x 22 columns]
#    app_id                        app_name  review_id language  \
# 0  359550  Tom Clancy's Rainbow Six Siege   42940414  english
# 1  359550  Tom Clancy's Rainbow Six Siege   42940324  english
# 2  359550  Tom Clancy's Rainbow Six Siege   42939922  english
# 3  359550  Tom Clancy's Rainbow Six Siege   42939480  english
# 4  359550  Tom Clancy's Rainbow Six Siege   42939386  english
#
#                                               review  timestamp_created  \
# 0                               Hey! Its pretty good         1529694109
# 1  This game is a near perfect blend of strategy,...         1529693877
# 2               Gets boring after 1700 hours but fun         1529692985
# 3                     it's a great multiplayer game.         1529692069
# 4  Its a good game, would rate it 8/10. Graphics ...         1529691836
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1529694109         True              1            0  ...
# 1         1529693877         True              0            0  ...
# 2         1605440226         True              1            0  ...
# 3         1529692069         True              0            0  ...
# 4         1542920054         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1            True              False                        False
# 2           False              False                        False
# 3            True              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198345420320                      13                   1
# 1  76561198154548001                      37                   5
# 2  76561198257856164                      57                   2
# 3  76561198440118114                      27                   2
# 4  76561198415144000                     120                   6
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                 228634.0                          1709.0
# 1                  75152.0                             0.0
# 2                 105609.0                             0.0
# 3                  17343.0                             0.0
# 4                  90257.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                    94321.0        1.610813e+09
# 1                    48826.0        1.589761e+09
# 2                   105385.0        1.609182e+09
# 3                      262.0        1.595612e+09
# 4                    76931.0        1.599102e+09
#
# [5 rows x 22 columns]
#    app_id  app_name  review_id language  \
# 0  945360  Among Us   76911308  english
# 1  945360  Among Us   76911306  english
# 2  945360  Among Us   76911267  english
# 3  945360  Among Us   76911237  english
# 4  945360  Among Us   76911196  english
#
#                                               review  timestamp_created  \
# 0  I mean, it's only $5 and it's a lot of fun. Be...         1601645026
# 1                                          good game         1601645023
# 2  2 minutes of silence, then 45 seconds of unint...         1601644976
# 3                                                 ee         1601644947
# 4                         My friends really do suck.         1601644887
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1601645026         True              0            0  ...
# 1         1601645023         True              0            0  ...
# 2         1606463399         True              0            0  ...
# 3         1601644947         True              0            0  ...
# 4         1601644887         True              0            1  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1            True              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4           False              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198044504930                      19                   1
# 1  76561198340314268                      17                   2
# 2  76561198986952056                      45                  14
# 3  76561199015573410                       8                   1
# 4  76561198220620645                     239                   9
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                    462.0                             0.0
# 1                   1060.0                             0.0
# 2                   3546.0                            20.0
# 3                   7607.0                             0.0
# 4                    970.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                      206.0        1.605442e+09
# 1                      852.0        1.609362e+09
# 2                     3408.0        1.610795e+09
# 3                     2316.0        1.609111e+09
# 4                      332.0        1.602417e+09
#
# [5 rows x 22 columns]
#    app_id app_name  review_id language  \
# 0  252490     Rust   57327702  english
# 1  252490     Rust   57327662  english
# 2  252490     Rust   57327446  english
# 3  252490     Rust   57327424  english
# 4  252490     Rust   57327154  english
#
#                                               review  timestamp_created  \
# 0                                          Big Gayme         1573954256
# 1           FUCKING HACKING CUNTS ALL OVER THE PLACE         1573954221
# 2                                      LUL GOOD GAME         1573953923
# 3                                       i like toxic         1573953898
# 4  very good game for what it is. but only if you...         1573953482
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1573954256         True              0            0  ...
# 1         1573954221        False              2            0  ...
# 2         1573953923         True              0            0  ...
# 3         1573953898         True              0            0  ...
# 4         1573953482         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1           False              False                        False
# 2            True              False                        False
# 3            True               True                        False
# 4           False              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198121223513                      43                   3
# 1  76561198347195276                       5                   2
# 2  76561198058889012                      66                  28
# 3  76561198830471366                      21                   7
# 4  76561198059153369                     154                  15
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                  59693.0                          1070.0
# 1                 190222.0                           140.0
# 2                  10058.0                             0.0
# 3                  35737.0                             0.0
# 4                   2105.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                    56884.0        1.610759e+09
# 1                   179536.0        1.610242e+09
# 2                     1801.0        1.603259e+09
# 3                    26830.0        1.597015e+09
# 4                     2061.0        1.574042e+09
#
# [5 rows x 22 columns]
#    app_id app_name  review_id language  \
# 0  648800     Raft   59563733  english
# 1  648800     Raft   59563584  english
# 2  648800     Raft   59563043  english
# 3  648800     Raft   59562997  english
# 4  648800     Raft   59562481  english
#
#                                               review  timestamp_created  \
# 0                                                Yes         1575909097
# 1                       i liek it it is fun and good         1575908926
# 2  great game for 100 percent beter with your fri...         1575908219
# 3  This game good. It's just really good.Alone, i...         1575908139
# 4                                           Rafting!         1575907463
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1575909097         True              0            0  ...
# 1         1575908926         True              0            0  ...
# 2         1575908219         True              0            1  ...
# 3         1575908139         True              0            0  ...
# 4         1575907463         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                         True
# 1            True              False                         True
# 2            True              False                         True
# 3            True              False                         True
# 4            True              False                         True
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198074093291                      32                   2
# 1  76561197973182043                     165                   6
# 2  76561198098086627                      53                   6
# 3  76561198442074851                      57                  18
# 4  76561197969053410                      64                   1
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   1045.0                             0.0
# 1                   1188.0                             0.0
# 2                   4187.0                             0.0
# 3                   3873.0                             0.0
# 4                   2432.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                      422.0        1.577911e+09
# 1                      792.0        1.609702e+09
# 2                     2315.0        1.602678e+09
# 3                      740.0        1.607802e+09
# 4                      675.0        1.603059e+09
#
# [5 rows x 22 columns]
#    app_id      app_name  review_id language  \
# 0  739630  Phasmophobia   76513664  english
# 1  739630  Phasmophobia   76513621  english
# 2  739630  Phasmophobia   76513317  english
# 3  739630  Phasmophobia   76513226  english
# 4  739630  Phasmophobia   76513142  english
#
#                                               review  timestamp_created  \
# 0                                      very fun yaes         1601001886
# 1  Ngl, I've almost shit my pants multiple times ...         1601001824
# 2                                          IT SPOOPY         1601001286
# 3  This game is the first game in a while where I...         1601001137
# 4  Literally one of the scariest games I have eve...         1601000989
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1601001886         True              0            0  ...
# 1         1601001824         True              1            0  ...
# 2         1601001286         True              2            1  ...
# 3         1601001137         True              1            0  ...
# 4         1601000989         True              1            1  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0           False              False                         True
# 1            True              False                         True
# 2            True              False                         True
# 3           False              False                         True
# 4            True              False                         True
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198127445545                      95                   6
# 1  76561198399331631                      30                   4
# 2  76561198012570928                      89                   1
# 3  76561198353546671                      61                   8
# 4  76561198082672482                     188                   3
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   6810.0                             0.0
# 1                   4140.0                             0.0
# 2                   4882.0                           257.0
# 3                   1991.0                             0.0
# ...
#
#                                               review  timestamp_created  \
# 0  I almost don't know how to formulate the prope...         1403494839
# 1  Amazing game, lots of fun to play alone, and e...         1403494802
# 2  149 hours of awesomeness. Honestly, I expected...         1403494783
# 3                          Terraria, not a bad game.         1403494428
# 4  I'm not giving it a thumbs down because it rem...         1403494365
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1403494839         True              0            0  ...
# 1         1403494802         True              0            0  ...
# 2         1403494783         True              0            0  ...
# 3         1474861719         True              0            0  ...
# 4         1403494365        False             12            2  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1            True              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4           False              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198076197398                     135                   1
# 1  76561198097521278                     371                   5
# 2  76561198042000064                      79                   1
# 3  76561198058189789                     426                   6
# 4  76561198046999341                     109                  64
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                  31932.0                             0.0
# 1                  11793.0                             0.0
# 2                  12890.0                             0.0
# 3                  45104.0                             4.0
# 4                    105.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                    17963.0        1.552101e+09
# 1                     4292.0        1.589849e+09
# 2                     8995.0        1.507225e+09
# 3                    13883.0        1.610919e+09
# 4                      105.0        1.396693e+09
#
# [5 rows x 22 columns]
#    app_id  app_name  review_id language  \
# 0  218620  PAYDAY 2   10331881  english
# 1  218620  PAYDAY 2   10331854  english
# 2  218620  PAYDAY 2   10331640  english
# 3  218620  PAYDAY 2   10331625  english
# 4  218620  PAYDAY 2   10331587  english
#
#                                               review  timestamp_created  \
# 0  Badass game if you have enought time to play o...         1401783481
# 1  very good game a bit unfinished in some areas ...         1401783069
# 2                                                yes         1401780867
# 3  Great game, as long as the party you are playi...         1401780702
# 4  I don't really know where to begin with Payday...         1401780286
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1401783481         True              0            0  ...
# 1         1401783069         True              1            0  ...
# 2         1401780867         True              0            0  ...
# 3         1401780702         True              0            0  ...
# 4         1401780286         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0           False              False                        False
# 1           False              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4           False              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198058667059                     123                   2
# 1  76561198065194670                     165                   1
# 2  76561198056858293                      63                   2
# 3  76561198067258054                     292                  15
# 4  76561198028465135                    1235                  21
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   1363.0                             0.0
# 1                   3976.0                             0.0
# 2                   8654.0                             0.0
# 3                   8918.0                          1113.0
# 4                  23976.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                     1363.0        1.401644e+09
# 1                      326.0        1.558192e+09
# 2                     2224.0        1.444885e+09
# 3                      743.0        1.611035e+09
# 4                     1301.0        1.503765e+09
#
# [5 rows x 22 columns]
#    app_id                                     app_name  review_id language  \
# 0  489830  The Elder Scrolls V: Skyrim Special Edition   68675154  english
# 1  489830  The Elder Scrolls V: Skyrim Special Edition   68674806  english
# 2  489830  The Elder Scrolls V: Skyrim Special Edition   68673403  english
# 3  489830  The Elder Scrolls V: Skyrim Special Edition   68672722  english
# 4  489830  The Elder Scrolls V: Skyrim Special Edition   68669454  english
#
#                                               review  timestamp_created  \
# 0  What can I say, the best game ever?The BEST GA...         1588772690
# 1                                               good         1588772228
# 2  Skyrim, for me, is one of the greatest games e...         1588770478
# 3        Hands down best game of all time. iGN 10/10         1588769597
# 4                                              wewew         1588765053
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1588772690         True              0            0  ...
# 1         1591709306         True              1            0  ...
# 2         1588770478         True              1            0  ...
# 3         1588769597         True              0            1  ...
# 4         1588765053         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1            True              False                        False
# 2           False              False                        False
# 3           False              False                        False
# 4           False              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198320854803                     112                   8
# 1  76561198282201987                      17                   9
# 2  76561198270161210                      35                   4
# 3  76561198058209736                      67                   8
# 4  76561198054070886                      55                   1
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                  33707.0                             0.0
# 1                   3166.0                             0.0
# 2                    401.0                             0.0
# 3                   7098.0                             0.0
# 4                   4612.0                           141.0
#
#    author.playtime_at_review  author.last_played
# 0                    27915.0        1.593310e+09
# 1                     2633.0        1.603555e+09
# 2                      401.0        1.586809e+09
# 3                     4287.0        1.598826e+09
# 4                     1612.0        1.610488e+09
#
# [5 rows x 22 columns]
#    app_id app_name  review_id language  \
# 0  107410   Arma 3   56147099  english
# 1  107410   Arma 3   56146139  english
# 2  107410   Arma 3   56145584  english
# 3  107410   Arma 3   56144824  english
# 4  107410   Arma 3   56144716  english
#
#                                               review  timestamp_created  \
# 0                                            is good         1572616014
# 1                          its a realistic army game         1572615563
# 2  This game is poorly optimised, made with littl...         1572615293
# 3                                     www.anzus.life         1572614939
# 4  its a rely realistic game if you get the ace m...         1572614891
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1572616014         True              0            0  ...
# 1         1572615563         True              0            0  ...
# 2         1572615293         True              1            0  ...
# 3         1572614939         True              0            0  ...
# 4         1572614891         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1            True              False                        False
# 2           False              False                        False
# 3            True              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198259166064                      86                  15
# 1  76561198982716628                      10                   3
# 2  76561198209031711                      77                   6
# 3  76561198801433109                      26                   1
# 4  76561198880536080                      15                   3
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                  23036.0                             0.0
# 1                    752.0                             0.0
# 2                 172005.0                          3282.0
# 3                 173507.0                             0.0
# 4                 132732.0                            40.0
#
#    author.playtime_at_review  author.last_played
# 0                    17155.0        1.609879e+09
# 1                      590.0        1.601048e+09
# 2                    93580.0        1.611081e+09
# 3                    64250.0        1.604860e+09
# 4                    13798.0        1.610899e+09
#
# [5 rows x 22 columns]
#    app_id      app_name  review_id language  \
# 0  517630  Just Cause 4   47309931  english
# 1  517630  Just Cause 4   47309902  english
# 2  517630  Just Cause 4   47309895  english
# 3  517630  Just Cause 4   47309873  english
# 4  517630  Just Cause 4   47309847  english
#
#                                               review  timestamp_created  \
# 0  UPDATE: Okay so, they did start fixing the iss...         1544023406
# 1  This game is absolutely broken right now. All ...         1544023317
# 2  Honestly, this is just my opinion of the game ...         1544023284
# 3  The lack of a Chaos System completely ruins an...         1544023187
# 4  This game looks like shit and runs like shit. ...         1544023090
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1574864101         True              2            0  ...
# 1         1562438660        False              6            1  ...
# 2         1561847105         True              1            3  ...
# 3         1597793278        False              0            0  ...
# 4         1544023090        False              4            1  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1           False              False                        False
# 2           False              False                        False
# 3           False              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198085401308                     178                  17
# 1  76561198041136256                     642                  34
# 2  76561198022085812                     553                 111
# 3  76561198251657048                     677                  71
# 4  76561198025932380                    1114                 124
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   6560.0                             0.0
# 1                   1731.0                             0.0
# 2                   1841.0                             0.0
# 3                    366.0                             0.0
# 4                     27.0                             0.0
#
#    author.playtime_at_review  author.last_played
# 0                      262.0        1.577129e+09
# 1                      168.0        1.603544e+09
# 2                      806.0        1.575685e+09
# 3                      366.0        1.553411e+09
# 4                       27.0        1.543979e+09
#
# [5 rows x 22 columns]
#    app_id       app_name  review_id language  \
# 0  367520  Hollow Knight   74185175  english
# 1  367520  Hollow Knight   74184624  english
# 2  367520  Hollow Knight   74184324  english
# 3  367520  Hollow Knight   74183833  english
# 4  367520  Hollow Knight   74182847  english
#
#                                               review  timestamp_created  \
# 0  a very beautiful game with splendind art style...         1597235981
# 1                                            Awesome         1597235135
# 2  I almost quit so many times. I only kept going...         1597234672
# 3          9/10 Would lose 10hrs in steel soul again         1597233890
# 4                                                fun         1597232205
#
#    timestamp_updated  recommended  votes_helpful  votes_funny  ...  \
# 0         1597235981         True              0            0  ...
# 1         1597235135         True              0            0  ...
# 2         1597234672        False              4            0  ...
# 3         1597233890         True              0            0  ...
# 4         1597232205         True              0            0  ...
#
#    steam_purchase  received_for_free  written_during_early_access  \
# 0            True              False                        False
# 1            True              False                        False
# 2            True              False                        False
# 3            True              False                        False
# 4            True              False                        False
#
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561198263729768                      59                  14
# 1  76561198151866365                       6                   2
# 2  76561198048292798                     155                  22
# 3  76561198281365217                      25                   2
# 4  76561198378023338                      37                   1
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                    580.0                             0.0
# 1                   2792.0                             0.0
# 2                   2180.0                             0.0
# 3                   7813.0                             0.0
# 4                  29531.0                           676.0
#
#    author.playtime_at_review  author.last_played
# 0                      291.0        1.608549e+09
# 1                      245.0        1.600523e+09
# 2                     1805.0        1.597263e+09
# 3                     5918.0        1.599249e+09
# 4                     1236.0        1.609713e+09
#
# [5 rows x 22 columns]
# Finished ingesting data into the postgres database

# %%
source_path = "/home/aliciescont/Documents/Github/dezoomcamp-project/data/steam_reviews.csv"
df_iter = pd.read_csv(source_path, iterator=True, chunksize=500000, index_col=0)
for chunk in df_iter:
    print(chunk['review_id'].head())
# Out:
# 0    85185598
# 1    85185250
# 2    85185111
# 3    85184605
# 4    85184287
# Name: review_id, dtype: int64
# 500001    49797168
# 500002    49794752
# 500003    49792060
# 500004    49789951
# 500005    49774359
# Name: review_id, dtype: int64
# 1000001    71813207
# 1000002    71812793
# 1000003    71812562
# 1000004    71812466
# 1000005    71812190
# Name: review_id, dtype: int64
# 1500001    11020694
# 1500002    11020664
# 1500003    11020579
# 1500004    11020489
# 1500005    11020478
# Name: review_id, dtype: int64
# 2000001    46558987
# 2000002    46558911
# 2000003    46558893
# 2000004    46558731
# 2000005    46558581
# Name: review_id, dtype: int64
# 2500001    65135149
# 2500002    65134915
# 2500003    65134596
# 2500004    65134520
# 2500005    65134436
# Name: review_id, dtype: int64
# 3000001    13749986
# 3000002    13749898
# 3000003    13749755
# 3000004    13749409
# 3000005    13749401
# Name: review_id, dtype: int64
# 3500001    71410139
# 3500002    71404778
# 3500003    71403172
# 3500004    71401274
# 3500005    71393256
# Name: review_id, dtype: int64
# 4000001    49326932
# 4000002    49326880
# 4000003    49326843
# 4000004    49326722
# 4000005    49326419
# Name: review_id, dtype: int64
# 4500001    83368049
# 4500002    83367950
# 4500003    83367894
# 4500004    83367575
# 4500005    83367529
# Name: review_id, dtype: int64
# 5000001    74032272
# 5000002    74031951
# 5000003    74031792
# 5000004    74031759
# 5000005    74031627
# Name: review_id, dtype: int64
# 5500001    81439989
# 5500002    81439834
# 5500003    81439770
# 5500004    81439652
# 5500005    81439369
# Name: review_id, dtype: int64
# 6000001    72041688
# 6000002    72041665
# 6000003    72041661
# 6000004    72041550
# 6000005    72041541
# Name: review_id, dtype: int64
# 6500001    42940679
# 6500002    42940483
# 6500003    42940414
# 6500004    42940324
# 6500005    42940248
# Name: review_id, dtype: int64
# 7000001    76911308
# 7000002    76911306
# 7000003    76911267
# 7000004    76911237
# 7000005    76911212
# Name: review_id, dtype: int64
# 7500001    57327702
# 7500002    57327675
# 7500003    57327662
# 7500004    57327531
# 7500005    57327446
# Name: review_id, dtype: int64
# 8000001    59563850
# 8000002    59563733
# 8000003    59563584
# 8000004    59563560
# 8000005    59563431
# Name: review_id, dtype: int64
# 8500001    76513664
# 8500002    76513621
# 8500003    76513317
# 8500004    76513226
# 8500005    76513158
# Name: review_id, dtype: int64
# 9000002    50463159
# 9000003    50463082
# 9000004    50463004
# 9000005    50462588
# 9000006    50462567
# Name: review_id, dtype: int64
# 9500002    2240068
# 9500003    2748619
# 9500004    2143522
# 9500005    1575628
# 9500006    2580462
# Name: review_id, dtype: int64
# 10000002    53011639
# 10000003    53011606
# 10000004    53011596
# 10000005    53011567
# 10000006    53011565
# Name: review_id, dtype: int64
# 10500002    38388475
# 10500003    38387842
# 10500004    38387369
# 10500005    38386549
# 10500006    38384178
# Name: review_id, dtype: int64
# 11000002    83704872
# 11000003    83700204
# 11000004    83698600
# 11000005    83697077
# 11000006    83696055
# Name: review_id, dtype: int64
# 11500002    20607493
# 11500003    20606094
# 11500004    20604825
# 11500005    20604703
# 11500006    20604103
# Name: review_id, dtype: int64
# 12000002    45790581
# 12000003    45788546
# 12000004    45784211
# 12000005    45776231
# 12000006    45770908
# Name: review_id, dtype: int64
# 12500002    69391634
# 12500003    69391409
# 12500004    69391157
# 12500005    69390333
# 12500006    69390163
# Name: review_id, dtype: int64
# 13000004    65871141
# 13000005    65871106
# 13000006    65871066
# 13000007    65871040
# 13000008    65871022
# Name: review_id, dtype: int64
# 13500004    33486532
# 13500005    33486472
# 13500006    33486455
# 13500007    33486439
# 13500008    33486406
# Name: review_id, dtype: int64
# 14000004    68626567
# 14000005    68626510
# 14000006    68626417
# 14000007    68626351
# 14000008    68626335
# Name: review_id, dtype: int64
# 14500004    48486091
# 14500005    48486074
# 14500006    48486048
# 14500007    48486024
# 14500008    48486006
# Name: review_id, dtype: int64
# 15000004    37920075
# 15000005    37920067
# 15000006    37920057
# 15000007    37920049
# 15000008    37920039
# Name: review_id, dtype: int64
# 15500004    63645867
# 15500005    63645854
# 15500006    63645790
# 15500007    63645649
# 15500008    63645540
# Name: review_id, dtype: int64
# 16000004    27001867
# 16000005    27001196
# 16000006    27000620
# 16000007    26999412
# 16000008    26999302
# Name: review_id, dtype: int64
# 16500004    57109531
# 16500005    57109529
# 16500006    57109360
# 16500007    57109333
# 16500008    57109258
# Name: review_id, dtype: int64
# 17000004    46992836
# 17000005    46992814
# 17000006    46992170
# 17000007    46991465
# 17000008    46991085
# Name: review_id, dtype: int64
# 17500004    39129798
# 17500005    39129715
# 17500006    39129608
# 17500007    39129298
# 17500008    39128997
# Name: review_id, dtype: int64
# 18000004    46095162
# 18000005    46092321
# 18000006    46091676
# 18000007    46090285
# 18000008    46088795
# Name: review_id, dtype: int64
# 18500004    71434988
# 18500005    71434858
# 18500006    71434778
# 18500007    71434742
# 18500008    71434707
# Name: review_id, dtype: int64
# 19000004    10694740
# 19000005    10694550
# 19000006    10694531
# 19000007    10694527
# 19000008    10694381
# Name: review_id, dtype: int64
# 19500004    10331939
# 19500005    10331881
# 19500006    10331854
# 19500007    10331839
# 19500008    10331823
# Name: review_id, dtype: int64
# 20000004    68675252
# 20000005    68675154
# 20000006    68674806
# 20000007    68673945
# 20000008    68673504
# Name: review_id, dtype: int64
# 20500004    56147720
# 20500005    56147234
# 20500006    56147099
# 20500007    56146793
# 20500008    56146732
# Name: review_id, dtype: int64
# 21000005    47310064
# 21000006    47310054
# 21000007    47310027
# 21000008    47309996
# 21000009    47309975
# Name: review_id, dtype: int64
# 21500005    74187392
# 21500006    74187295
# 21500007    74187237
# 21500008    74187027
# 21500009    74186846
# Name: review_id, dtype: int64

# %%
pd.io.json.build_table_schema(df)
# Out:
# {'fields': [{'name': 'index', 'type': 'integer'},
#   {'name': 'Unnamed: 0', 'type': 'integer'},
#   {'name': 'app_id', 'type': 'integer'},
#   {'name': 'app_name', 'type': 'string'},
#   {'name': 'review_id', 'type': 'integer'},
#   {'name': 'language', 'type': 'string'},
#   {'name': 'review', 'type': 'string'},
#   {'name': 'timestamp_created', 'type': 'integer'},
#   {'name': 'timestamp_updated', 'type': 'integer'},
#   {'name': 'recommended', 'type': 'boolean'},
#   {'name': 'votes_helpful', 'type': 'integer'},
#   {'name': 'votes_funny', 'type': 'integer'},
#   {'name': 'weighted_vote_score', 'type': 'number'},
#   {'name': 'comment_count', 'type': 'integer'},
#   {'name': 'steam_purchase', 'type': 'boolean'},
#   {'name': 'received_for_free', 'type': 'boolean'},
#   {'name': 'written_during_early_access', 'type': 'boolean'},
#   {'name': 'author.steamid', 'type': 'integer'},
#   {'name': 'author.num_games_owned', 'type': 'integer'},
#   {'name': 'author.num_reviews', 'type': 'integer'},
#   {'name': 'author.playtime_forever', 'type': 'number'},
#   {'name': 'author.playtime_last_two_weeks', 'type': 'number'},
#   {'name': 'author.playtime_at_review', 'type': 'number'},
#   {'name': 'author.last_played', 'type': 'number'}],
#  'primaryKey': ['index'],
#  'pandas_version': '1.4.0'}

# %%
df_iter = pd.read_csv("/home/aliciescont/Documents/Github/dezoomcamp-project/data/steam_reviews.csv", iterator=True, chunksize=10000)

# %%
df = next(df_iter)
print(df['review_id'].head())
# Out:
# 340000    37885649
# 340001    37885461
# 340002    37885284
# 340003    37885230
# 340004    37885130
# Name: review_id, dtype: int64

# %%
def clean(df: pd.DataFrame) -> pd.DataFrame:
    """Fix dtype issues"""

    df["timestamp_created"] = pd.to_datetime(df["timestamp_updated"], utc=True, unit='s')
    df["timestamp_updated"] = pd.to_datetime(df["timestamp_updated"], utc=True, unit='s')
    print(df.head(2))
    print(f"columns: {df.dtypes}")
    print(f"rows: {len(df)}")
    return df

# %%
def batch_to_parquet(df: pd.DataFrame, dataset_file: str, index_file: int) -> Path:
    """Write DataFrame out locally as parquet file"""
    path = Path(f"{dataset_file}_{index_file}.csv") 
    df.to_csv(path)
    return path

# %%
def etl_web_to_gcs() -> None:
    """The main ETL function"""
    
    source_path = "/home/aliciescont/Documents/Github/dezoomcamp-project/data/steam_reviews.csv"
  
    df = fetch(source_path)
    index_file = 0
    output_path = Path(f"data/steam_reviews_{index_file}.csv")
    while True:
        try:
            index_file += 1
            df_next = fetch(df_iter)
            print(df_next.head())
            path = batch_to_parquet(df, source_path, index_file)

        except StopIteration:
            print("Finished ingesting data into the postgres database")
            break 
    #df_clean = clean(df)
    return path

# %%
etl_web_to_gcs()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 etl_web_to_gcs()
#
# Cell In[84], line 6, in etl_web_to_gcs()
#       2 """The main ETL function"""
#       4 source_path = "/home/aliciescont/Documents/Github/dezoomcamp-project/data/steam_reviews.csv"
# ----> 6 df = fetch(source_path)
#       7 index_file = 0
#       8 output_path = Path(f"data/steam_reviews_{index_file}.csv")
#
# Cell In[25], line 3, in fetch(df_iter)
#       1 def fetch(df_iter: pd.DataFrame) -> pd.DataFrame:
#       2     """Read taxi data from web into pandas DataFrame"""
# ----> 3     df = next(df_iter)
#       4     #df["timestamp_created"] = pd.to_datetime(df["timestamp_updated"], utc=True, unit='s')
#       5     #df["timestamp_updated"] = pd.to_datetime(df["timestamp_updated"], utc=True, unit='s')
#       6     print(df['review_id'].head())
#
# TypeError: 'str' object is not an iterator

# %%
    index_file = 0
    while True:
        index_file += 1
        try:   
            etl_web_to_gcs(index_file)

        except StopIteration:
            print("Finished ingesting data into the postgres database")
            break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 5
#       3 index_file += 1
#       4 try:
# ----> 5     etl_web_to_gcs(index_file)
#       7 except StopIteration:
#       8     print("Finished ingesting data into the postgres database")
#
# Cell In[25], line 9, in etl_web_to_gcs(index_file)
#       7 df = fetch(source_path)
#       8 #df_clean = clean(df)
# ----> 9 path = batch_to_parquet(df, source_path, index_file)
#      10 return path
#
# Cell In[8], line 4, in batch_to_parquet(df, dataset_file, index_file)
#       2 """Write DataFrame out locally as parquet file"""
#       3 path = Path(f"{dataset_file}_{index_file}.csv")
# ----> 4 df.to_csv(path)
#       5 return path
#
# File ~/anaconda3/envs/dezoomcamp-project/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dezoomcamp-project/lib/python3.9/site-packages/pandas/core/generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File ~/anaconda3/envs/dezoomcamp-project/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dezoomcamp-project/lib/python3.9/site-packages/pandas/io/formats/format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File ~/anaconda3/envs/dezoomcamp-project/lib/python3.9/site-packages/pandas/io/formats/csvs.py:261, in CSVFormatter.save(self)
#     241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#    (...)
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
# --> 261     self._save()
#
# File ~/anaconda3/envs/dezoomcamp-project/lib/python3.9/site-packages/pandas/io/formats/csvs.py:266, in CSVFormatter._save(self)
#     264 if self._need_to_save_header:
#     265     self._save_header()
# --> 266 self._save_body()
#
# File ~/anaconda3/envs/dezoomcamp-project/lib/python3.9/site-packages/pandas/io/formats/csvs.py:304, in CSVFormatter._save_body(self)
#     302 if start_i >= end_i:
#     303     break
# --> 304 self._save_chunk(start_i, end_i)
#
# File ~/anaconda3/envs/dezoomcamp-project/lib/python3.9/site-packages/pandas/io/formats/csvs.py:315, in CSVFormatter._save_chunk(self, start_i, end_i)
#     312 data = [res.iget_values(i) for i in range(len(res.items))]
#     314 ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 315 libwriters.write_csv_rows(
#     316     data,
#     317     ix,
#     318     self.nlevels,
#     319     self.cols,
#     320     self.writer,
#     321 )
#
# File ~/anaconda3/envs/dezoomcamp-project/lib/python3.9/site-packages/pandas/_libs/writers.pyx:55, in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:
